# %%
# !pip install transformers nltk accelerate

import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('semcor')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.25.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (3.7)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.8/dist-packages (0.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.11.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from accelerate) (1.13.0+cu116)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from accelerate) (5.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.9.24)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package semcor to /root/nltk_data...
# [nltk_data]   Package semcor is already up-to-date!
# True

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer


class TransFilter:
    """
    Given a dict of the form {synset: best_hyponym}, removes from the dict
    the synsets that are too complicated for humans to understand (keep only basic words)
    """

    def __init__(self, synsets: dict):
        self.synsets = synsets
        self.filtered_synsets = {}
        checkpoint = "facebook/opt-6.7b"
        self.tokenizer = AutoTokenizer.from_pretrained(checkpoint)
        self.model = AutoModelForCausalLM.from_pretrained(checkpoint, torch_dtype="auto", device_map="auto")

    def batch_processing(self, batch_size=100):
        """
        Process the synsets in batches of size batch_size
        """
        synsets = list(self.synsets.keys())
        for i in range(0, len(synsets), batch_size):
            batch = synsets[i:i + batch_size]
            self.process_batch(batch)

    def process_batch(self, batch):
        """
        Process a batch of synsets
        """
        for synset in batch:
            if self.is_too_complicated(synset):
                print(f"Removing {synset.lemma_names()[0]}")
            else:
                self.filtered_synsets[synset] = self.synsets[synset]

    def is_too_complicated(self, synset) -> bool:
        """
        Returns True if the synset is too complicated for humans to understand
        """
        inputs = self.tokenizer.encode(
            f"Is this a simple english word (example: dog -> yes, discombobulated -> no, beach -> yes, acquaintance -> no)? {synset.lemma_names()[0]} ->",return_tensors="pt").to("cuda")
        outputs = self.model.generate(inputs)
        return self.tokenizer.decode(outputs[0], skip_special_tokens=True)[-2:] == "no"

    def get_synsets(self) -> dict:
        return self.synsets

    def get_filtered_synsets(self) -> dict:
        return self.filtered_synsets

# %%
from collections import Counter

import nltk


def filter_synsets(synset_counter, common_nouns_synsets, n) -> list:
    most_common_synsets = [synset for synset, _ in synset_counter.most_common(n)]
    flush_set = set()
    for synset_list in common_nouns_synsets:
        for synset in synset_list:
            flush_set.add(synset)
    for synset in most_common_synsets:
        flush_set.add(synset)
    # Return most_common_synsets + flush_set
    return list(flush_set)


def retrieve_ogden_words() -> list:
    """
    Returns a list of words from the Ogden Basic English Dictionary
    ogden.txt is a one-line file containing all the words, split by commas
    """
    with open('ogden.txt', 'r') as f:
        words = f.read()
    return words.split(',')


def retrieve_common_nouns() -> list:
    """
    Returns a list of common nouns from the Common Nouns list
    common_nouns.txt is a multi-line file containing all the words
    """
    with open('common_nouns.txt', 'r') as f:
        words = f.read()
    return words.split('\n')


def synset_converter(words) -> list:
    """
    Converts words to synsets
    """
    return [nltk.corpus.wordnet.synsets(word) for word in words]


def count_synsets(synsets) -> Counter:
    """
    Counts the synsets
    """
    synset_counter = Counter()
    synset_counter.update(synsets)
    return synset_counter


def isolate_nouns(synsets) -> list:
    """
    Isolates nouns from synsets
    """
    final_synsets = set()
    for syn_list in synsets:
        if syn_list:
            for synset in syn_list:
                if synset.pos() == 'n':
                    final_synsets.add(synset)
    return list(final_synsets)


def get_best_synsets(n) -> list:
    """
    Returns the most frequent synsets
    """
    ogden_words = retrieve_ogden_words()
    common_nouns = retrieve_common_nouns()
    words = semcor.words()
    ogden_synsets = synset_converter(ogden_words)
    common_nouns_synsets = synset_converter(common_nouns)
    word_synsets = synset_converter(words)
    merged_synsets = ogden_synsets + word_synsets
    synsets = isolate_nouns(merged_synsets)
    synset_counter = count_synsets(synsets)
    return filter_synsets(synset_counter, common_nouns_synsets, n)


def get_most_frequent_hyponyms(most_frequent_synsets) -> dict:
    """
    Returns the most frequent hyponyms.
    Build a dictionary of the form {synset: best_hyponym}
    where the best_hyponym is the hyponym with the highest frequency
    and not too close with his hypernym
    """
    return get_best_hyponym(get_hyponyms(most_frequent_synsets))


def get_hyponyms(most_frequent_synsets) -> dict:
    return {synset: list(set([i for i in synset.closure(lambda s:s.hyponyms())])) + synset.hypernyms() for synset in most_frequent_synsets}


def get_best_hyponym(hyponyms: dict):
    return {synset: get_best_hyponym_from_list(hyponym_list, synset) for synset, hyponym_list in
            hyponyms.items()}


def get_best_hyponym_from_list(hyponym_list, synset) -> nltk.corpus.reader.wordnet.Synset:
    """
    Returns the best hyponym from a list of hyponyms.
    The best hyponym is the hyponym with a high frequency (in the top 10 of most frequent hyponyms)
    and not too close with his hypernym, with a path_similarity > 2.
    It is also required that the hypoynm cannot share a word with the hypernym.
    """
    for hyponym in hyponym_list:
        if hyponym.pos() == 'n' \
                and hyponym.path_similarity(synset) <= 0.63 \
                and is_in_top_10(hyponym, hyponym_list) \
                and not share_words(hyponym, synset) \
                and not is_common(hyponym):
            return hyponym
    for hyponym in hyponym_list:
        if hyponym.pos() == 'n' \
                and hyponym.path_similarity(synset) <= 0.63 \
                and not share_words(hyponym, synset) \
                and not is_common(hyponym):
            return hyponym
    return None


def is_in_top_10(hyponym, hyponym_list) -> bool:
    """
    Returns True if the hyponym is in the top 5 of most frequent hyponyms
    """
    hyponym_counter = Counter()
    hyponym_counter.update(hyponym_list)
    return hyponym in [hyponym for hyponym, _ in hyponym_counter.most_common(10)]


def share_words(hyponym, synset) -> bool:
    """
    Returns True if the hyponym and the synset share a word
    """
    for word in hyponym.lemma_names():
        for word2 in synset.lemma_names():
            if word in word2 or word2 in word:
                return True
    return False


def is_common(hyponym) -> bool:
    """
    Check if the hyponym's lexeme is a middle-concept
    """
    if len(synsets) == 0:
        # This should never happen, but just in case... (it happened)
        return False
    else:
        # Convert synsets in a list of their lexemes (words)
        synsets_lexemes = [synset.lemma_names() for synset in synsets]
        # Flatten the list
        synsets_lexemes = [item for sublist in synsets_lexemes for item in sublist]
        # Check if the hyponym's lexeme is in the list
        return hyponym.lemma_names()[0] in synsets_lexemes


def flush_to_file_hr(synsets, file_name) -> None:
    """
    Flushes the synsets, synonyms and hyponyms to a single file
    """
    for synset, hyponym in synsets.items():
        with open(file_name, 'a') as f:
            if synset and hyponym:
                f.write(f"Synset: {synset.name()} ({[str(lemma.name()) for lemma in synset.lemmas()][0]}) ||"
                        f" Hyponym: {hyponym.name()} || Synonyms: {synset.lemma_names()} || Hyponym's "
                        f"synonyms: {hyponym.lemma_names()}\n")


def flush_to_file_mr(synsets: dict, file_name: str, hyponym_file_name: str) -> None:
    """
    Flushes all the synset's lemmas (comma separated) to a file
    """
    flushed_synsets = set()
    flushed_hyponyms = set()
    for synset, hyponym in synsets.items():
        with open(file_name, 'a') as f:
            if synset and hyponym and synset not in flushed_synsets and synset not in flushed_hyponyms:
                lemmas = [str(lemma.name()).replace("_", " ") for lemma in synset.lemmas()]
                f.write(f"{','.join(lemmas)}\n")
        with open(hyponym_file_name, 'a') as f:
            if synset and hyponym and hyponym not in flushed_synsets and hyponym not in flushed_hyponyms:
                lemmas = [str(lemma.name()).replace("_", " ") for lemma in hyponym.lemmas()]
                f.write(f"{','.join(lemmas)}\n")
                flushed_hyponyms.add(hyponym)


def keep_it_1000(file_name: str) -> None:
    """
    Keeps the file with 1000 lines
    """
    with open(file_name, 'r') as f:
        lines = f.readlines()
    with open(file_name, 'w') as f:
        for line in lines[:1000]:
            f.write(line)


def main() -> None:
    """
    Main function
    """
    most_frequent_synsets = get_best_synsets(300)  # 300 is totally arbitrary, it WON'T be the final number.

    # Now we want to get the most frequent hyponyms of the most frequent synsets
    unfiltered_synsets = get_most_frequent_hyponyms(most_frequent_synsets)

    # Process the synsets to remove the ones that are not common english
    tf = TransFilter(unfiltered_synsets)
    tf.batch_processing()
    filtered_synsets = tf.get_filtered_synsets()

    # Flush everything to a file
    flush_to_file_mr(filtered_synsets, 'basic.txt', 'advanced.txt')
    # Keep only the first 1000 lines from the file
    keep_it_1000('basic.txt')
    keep_it_1000('advanced.txt')
    # stats(filtered_synsets)


if __name__ == '__main__':
    semcor = nltk.corpus.semcor
    synsets = []
    main()
# Out:
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gambling_house.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('house.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('dormitory.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('brewpub.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('lodging_house.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('skybox.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('alcazar.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('sconce.n.02') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('dry_wall.n.02') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('argon.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('helium.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('krypton.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('neon.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('sheep_dip.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('filtrate.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('germanium.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('silicon.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('limestone.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('carbolic_acid.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('carbon_tetrachloride.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('zeolite.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('fluorescein.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('bromophenol_blue.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('bromothymol_blue.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('red_clay.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('humic_shale.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('scrap_iron.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('alum.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('alum.n.02') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('paris_green.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('hydrazoic_acid.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('halite.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('calcium_carbide.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('furfural.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('toluene.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('chlorobenzene.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('naphtha.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('acetone.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('natural_resin.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('sterol.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('methylene_blue.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('sulfur_dioxide.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('nylon.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('lead_acetate.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gypsum.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('alum.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('alum.n.02') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('paris_green.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('tartar_emetic.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('calcimine.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('foam_rubber.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('absorbent_cotton.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('glucocorticoid.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('hexane.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('cellulose_nitrate.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('glyceride.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('chlorofluorocarbon.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('triglyceride.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('enzyme.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('epinephrine.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gamma_aminobutyric_acid.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('taconite.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gesso.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('drambuie.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('beta-carotene.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('animal_fat.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('animal_oil.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('beeswax.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('elaidic_acid.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('sucrose.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gas_oil.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('calcium_ion.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('immunoglobulin.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gamma_globulin.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('styrofoam.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('beta-hydroxybutyric_acid.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('noradrenaline.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('drying_oil.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('styrofoam.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('haitian_creole.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('wildflower.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('clematis.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('legume.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('american_holly.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('field_corn.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('habsburg.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('hanover.n.02') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('hohenzollern.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('lancaster.n.02') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('plantagenet.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('romanov.n.02') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('saxe-coburg-gotha.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('stuart.n.03') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('york.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('cranberry.n.02') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('almond.n.02') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('glucocorticoid.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('fishbowl.n.02') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('politics.n.05') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('amphibious_landing.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('stage_dancing.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('fencing.n.03') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('politics.n.05') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('tidal_wave.n.02') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('tsunami.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('potlatch.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('groundbreaking.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('judo.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('auscultation.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('palpation.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gambling.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('tirade.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('debriefing.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('protest_march.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('fatal_accident.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('manicure.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('pedicure.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('washup.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('rock_climbing.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_boxing.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_football.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_wrestling.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('sumo.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_basketball.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_tennis.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('football.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_golf.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('roentgenography.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('cardiac_massage.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('quantitative_analysis.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('thermogravimetry.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('protest_march.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('terrorist_attack.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('self-flagellation.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('cardiopulmonary_resuscitation.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_basketball.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_tennis.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('football.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_golf.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('electric_shock.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('vasectomy.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('jump_rope.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('unction.n.04') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('terrorist_attack.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('self-flagellation.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('dry-gulching.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('kickoff.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('singing.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_baseball.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('resisting_arrest.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('professional_baseball.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('freeze.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('thaw.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('maximum.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('temperature_scale.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('date.n.06') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('cent.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('stp.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('succoth.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('christmas.n.02') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('rosh_hashanah.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('argon.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('helium.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('krypton.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('neon.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('sheep_dip.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('filtrate.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('germanium.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('silicon.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('limestone.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('labial_stop.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('carbolic_acid.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('carbon_tetrachloride.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('zeolite.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('fluorescein.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('bromophenol_blue.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('bromothymol_blue.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('red_clay.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('humic_shale.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('scrap_iron.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('hydrazoic_acid.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('halite.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('calcium_carbide.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('furfural.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('toluene.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('chlorobenzene.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('naphtha.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('acetone.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('natural_resin.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('sterol.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('methylene_blue.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('sulfur_dioxide.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('nylon.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('lead_acetate.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gypsum.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('alum.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('alum.n.02') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('paris_green.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('tartar_emetic.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('calcimine.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('foam_rubber.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('absorbent_cotton.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('glucocorticoid.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('hexane.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('cellulose_nitrate.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('glyceride.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('chlorofluorocarbon.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('triglyceride.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('enzyme.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('epinephrine.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gamma_aminobutyric_acid.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('taconite.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gesso.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('drambuie.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('beta-carotene.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('animal_fat.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('animal_oil.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('beeswax.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('elaidic_acid.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('sucrose.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gas_oil.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('calcium_ion.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('immunoglobulin.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('gamma_globulin.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordnet.py:599: UserWarning: Discarded redundant search for Synset('beta-hydroxybutyric_acid.n.01') at depth 11
#   for synset in acyclic_breadth_first(self, rel, depth):
# ...
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing history
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 32, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 32, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 32, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 32, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing play
# Removing property
# Removing precipitate
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing reason
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 32, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing trouble
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing drop
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing device
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing alternate
# Removing plantation
# Removing cover
# Removing stumble
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 33, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing group
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 32, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 33, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 32, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 33, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing limit
# Removing play
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 34, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing overawe
# Removing stretch
# Removing show
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 33, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing play
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 33, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing break_down
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 32, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 32, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Removing note
# Removing palpate
# Removing chute
# Input length of input_ids is 38, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 31, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 32, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 33, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Hyponyms = 1579/3504 - Hypernyms = 1925/3504
